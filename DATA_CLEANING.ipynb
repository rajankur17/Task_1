# %%
import pandas as pd

# %%
df = pd.read_csv('sales.csv', encoding='latin-1')

# %%
df = df.head()

# %%
df.isnull().sum()

# %%
# DATA CLEANING
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

df = df.drop_duplicates()

text_cols = df.select_dtypes(include='object').columns
for col in text_cols:
    df[col] = df[col].astype(str).str.strip()

df['orderdate'] = pd.to_datetime(df['orderdate'], errors='coerce')

df = df.drop(columns=['addressline2'])
df['state'] = df['state'].fillna('Unknown')
df['territory'] = df['territory'].fillna('Unknown')
df['postalcode'] = df['postalcode'].fillna('00000')

df = df.convert_dtypes()

# %%
df.shape
# Out:
# (2823, 24)

# %%
df['ordernumber'] = df['ordernumber'].astype(str)

# %%
df.groupby('ordernumber')['sales'].sum()
# Out:
# ordernumber
# 10100    12133.25
# 10101    11432.34
# 10102     6864.05
# 10103     54702.0
# 10104    44621.96
#            ...
# 10421     7261.75
# 10422      6166.8
# 10423     8411.95
# 10424    35133.34
# 10425    43784.69
# Name: sales, Length: 307, dtype: Float64

# %%
df.isnull().sum()
# Out:
# ordernumber         0
# quantityordered     0
# priceeach           0
# orderlinenumber     0
# sales               0
# orderdate           0
# status              0
# qtr_id              0
# month_id            0
# year_id             0
# productline         0
# msrp                0
# productcode         0
# customername        0
# phone               0
# addressline1        0
# city                0
# state               0
# postalcode          0
# country             0
# territory           0
# contactlastname     0
# contactfirstname    0
# dealsize            0
# dtype: int64

# %%
df['postalcode'].isna().sum()
# Out:
# np.int64(0)

# %%
df['state'] = df['state'].replace('nan', 'Unknown')

# %%
# DATA CLEANING
df['state'] = df['state'].replace('nan', 'Unknown')
df['postalcode'] = df['postalcode'].astype(str).str.replace(r"[^0-9]", '', regex=True)
df['postalcode'] = df['postalcode'].replace('', '00000')
df['postalcode'] = df['postalcode'].fillna('00000')
df['territory'] = df['territory'].fillna('Unknown')

# %%
df = df.drop('is_valid_postalcode', axis=1)

# %%
df
# Out:
#      ordernumber  quantityordered  priceeach  orderlinenumber    sales  \
# 0          10107               30       95.7                2   2871.0
# 1          10121               34      81.35                5   2765.9
# 2          10134               41      94.74                2  3884.34
# 3          10145               45      83.26                6   3746.7
# 4          10159               49      100.0               14  5205.27
# ...          ...              ...        ...              ...      ...
# 2818       10350               20      100.0               15   2244.4
# 2819       10373               29      100.0                1  3978.51
# 2820       10386               43      100.0                4  5417.57
# 2821       10397               34      62.24                1  2116.16
# 2822       10414               47      65.52                9  3079.44
#
#       orderdate    status  qtr_id  month_id  year_id  ...             phone  \
# ...

# %%
df.dtypes
# Out:
# ordernumber                 object
# quantityordered              Int64
# priceeach                  Float64
# orderlinenumber              Int64
# sales                      Float64
# orderdate           datetime64[ns]
# status              string[python]
# qtr_id                       Int64
# month_id                     Int64
# year_id                      Int64
# productline         string[python]
# msrp                         Int64
# productcode         string[python]
# customername        string[python]
# phone               string[python]
# addressline1        string[python]
# city                string[python]
# state               string[python]
# postalcode                  object
# country             string[python]
# territory           string[python]
# contactlastname     string[python]
# contactfirstname    string[python]
# dealsize            string[python]
# dtype: object

# %%
# dowloading the cleaned dataset
from google.colab import files
df.to_csv('new_cleaned_sales.csv', encoding='utf-8', index=False)
files.download('new_cleaned_sales.csv')

# %%
df.describe()
# Out:
#        quantityordered  priceeach  orderlinenumber        sales  \
# count           2823.0     2823.0           2823.0       2823.0
# mean         35.092809  83.658544         6.466171  3553.889072
# min                6.0      26.88              1.0       482.13
# 25%               27.0      68.86              3.0      2203.43
# 50%               35.0       95.7              6.0       3184.8
# 75%               43.0      100.0              9.0       4508.0
# max               97.0      100.0             18.0      14082.8
# std           9.741443  20.174277         4.225841  1841.865106
#
#                            orderdate    qtr_id  month_id     year_id  \
# count                           2823    2823.0    2823.0      2823.0
# mean   2004-05-11 00:16:49.989373056  2.717676  7.092455  2003.81509
# min              2003-01-06 00:00:00       1.0       1.0      2003.0
# 25%              2003-11-06 12:00:00       2.0       4.0      2003.0
# ...
